# %%
import pandas as pd
import numpy as np
from preprocessing_function import shuffle
# Out:
# /tmp/ipykernel_8469/2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Choices

# %%
type_data = 'enhancer'
# type_data = 'promotor'
# type_data = 'enhancer_promotor'

# %% [markdown]
# # Import data

# %%
csv_file_path = f'../../../results_scbasset/data/CAGE/{type_data}.csv'

# %% [markdown]
# # Shuffle

# %%
shuffle(csv_file_path)
# Out:
#                                  Region  s15t1p2sq1  s15t2p2sq1  s15t3p2sq1  \
# 0                  chr1:629175-629265:+    6.986375    3.589432    2.036377
# 1                  chr1:629806-629930:+    1.056349    1.280115    0.046413
# 2                  chr1:630223-630315:+   13.902758   10.756526   11.475395
# 3                  chr1:631294-631361:+    3.448896    9.432785    2.882501
# 4                  chr1:632231-632378:+   60.336850   63.492452   65.913376
# ...                                 ...         ...         ...         ...
# 24693  chrUn_KI270438v1:109820-110002:-    0.000000    0.500484    0.560999
# 24694      chrUn_KI270744v1:6128-6215:-    0.000000    0.000000    0.000000
# 24695  chrUn_KI270744v1:105258-105259:-    0.000000    0.000000    0.000000
# 24696  chrUn_KI270744v1:112243-112244:-    2.914568    8.922094   10.030989
# 24697    chrUn_KI270746v1:52556-52562:-    0.000000    0.000000    0.000000
#
# ...

# %% [markdown]
# ## Save shuffle csv

# %%
df.to_csv(f'../../../results_scbasset/data/CAGE/shuffle_{type_data}.csv', index=False)
